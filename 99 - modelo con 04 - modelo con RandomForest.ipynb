# %%
# !wget --no-cache -O init.py -q https://raw.githubusercontent.com/rramosp/ai4eng.v1/main/content/init.py
import init; init.init(force_download=False); init.get_weblink()
# Out:
# <meta name="google-signin-client_id"
#       content="461673936472-kdjosv61up3ac1ajeuq6qqu72upilmls.apps.googleusercontent.com"/>
# <script src="https://apis.google.com/js/client:platform.js?onload=google_button_start"></script>
# replicating local resources
# <h3>See <a href='https://m5knaekxo6.execute-api.us-west-2.amazonaws.com/dev-v0001/rlxmooc/web/login' target='_blank'>my courses and progress</a></h2>

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '.'
# !chmod 600 ./kaggle.json
# !kaggle competitions download -c udea-ai4eng-20242
# Out:
# ...
#  45% 9.00M/20.1M [00:00<00:00, 89.7MB/s]
# 100% 20.1M/20.1M [00:00<00:00, 107MB/s]

# %%
# !unzip udea*.zip > /dev/null

# %%
# !wc *.csv
# Out:
#    296787    296787   4716673 submission_example.csv
#    296787   4565553  50135751 test.csv
#    692501  10666231 118025055 train.csv
#   1286075  15528571 172877479 total

# %% [markdown]
# ## load `train.csv` data with pandas

# %%
import pandas as pd
import numpy as np

z = pd.read_csv("train.csv")
print ("shape of loaded dataframe", z.shape)
# Out:
# shape of loaded dataframe (692500, 12)

# %%
z.head()
# Out:
#        ID  PERIODO         ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 0  904256    20212                  ENFERMERIA                 BOGOTÁ
# 1  645256    20212                     DERECHO              ATLANTICO
# 2  308367    20203       MERCADEO Y PUBLICIDAD                 BOGOTÁ
# 3  470353    20195  ADMINISTRACION DE EMPRESAS              SANTANDER
# 4  989032    20212                  PSICOLOGIA              ANTIOQUIA
#
#              ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 0  Entre 5.5 millones y menos de 7 millones       Menos de 10 horas
# 1  Entre 2.5 millones y menos de 4 millones                       0
# 2  Entre 2.5 millones y menos de 4 millones         Más de 30 horas
# 3  Entre 4 millones y menos de 5.5 millones                       0
# 4  Entre 2.5 millones y menos de 4 millones     Entre 21 y 30 horas
#
#   FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET                 FAMI_EDUCACIONPADRE  \
# ...

# %% [markdown]
# #Limpieza y desclasificación de variables

# %% [markdown]
# dropear ID

# %%
z.drop('ID', axis=1, inplace=True)

# %%
z.head()
# Out:
#    PERIODO         ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 0    20212                  ENFERMERIA                 BOGOTÁ
# 1    20212                     DERECHO              ATLANTICO
# 2    20203       MERCADEO Y PUBLICIDAD                 BOGOTÁ
# 3    20195  ADMINISTRACION DE EMPRESAS              SANTANDER
# 4    20212                  PSICOLOGIA              ANTIOQUIA
#
#              ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 0  Entre 5.5 millones y menos de 7 millones       Menos de 10 horas
# 1  Entre 2.5 millones y menos de 4 millones                       0
# 2  Entre 2.5 millones y menos de 4 millones         Más de 30 horas
# 3  Entre 4 millones y menos de 5.5 millones                       0
# 4  Entre 2.5 millones y menos de 4 millones     Entre 21 y 30 horas
#
#   FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET                 FAMI_EDUCACIONPADRE  \
# 0            Estrato 3                 Si    Técnica o tecnológica incompleta
# ...

# %% [markdown]
# convertir ESTU_PRGM_ACADEMICO y ESTU_PRGM_DEPARTAMENTO, FAMI_EDUCACIONPADRE, FAMI_EDUCACIONMADRE, FAMI_TIENEINTERNET, FAMI_ESTRATOVIVIENDA, ESTU_PAGOMATRICULAPROPIO valores numericos:

# %%
# Assign unique numeric values to each unique program
def cleaning_variables(dataframe):
  dataframe["ESTU_PRGM_ACADEMICO"] = dataframe["ESTU_PRGM_ACADEMICO"].astype("category").cat.codes
  dataframe["ESTU_PRGM_DEPARTAMENTO"] = dataframe["ESTU_PRGM_DEPARTAMENTO"].astype("category").cat.codes
  dataframe["FAMI_EDUCACIONPADRE"] = dataframe["FAMI_EDUCACIONPADRE"].astype("category").cat.codes
  dataframe["FAMI_EDUCACIONMADRE"] = dataframe["FAMI_EDUCACIONMADRE"].astype("category").cat.codes
  dataframe["FAMI_TIENEINTERNET"] = dataframe["FAMI_TIENEINTERNET"].astype("category").cat.codes
  dataframe["FAMI_ESTRATOVIVIENDA"] = dataframe["FAMI_ESTRATOVIVIENDA"].astype("category").cat.codes
  dataframe["ESTU_PAGOMATRICULAPROPIO"] = dataframe["ESTU_PAGOMATRICULAPROPIO"].astype("category").cat.codes
# Display the DataFrame
cleaning_variables(z)

# %%
z.head()
# Out:
#    PERIODO  ESTU_PRGM_ACADEMICO  ESTU_PRGM_DEPARTAMENTO  \
# 0    20212                  300                       4
# 1    20212                  249                       3
# 2    20203                  819                       4
# 3    20195                   14                      26
# 4    20212                  907                       1
#
#              ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 0  Entre 5.5 millones y menos de 7 millones       Menos de 10 horas
# 1  Entre 2.5 millones y menos de 4 millones                       0
# 2  Entre 2.5 millones y menos de 4 millones         Más de 30 horas
# 3  Entre 4 millones y menos de 5.5 millones                       0
# 4  Entre 2.5 millones y menos de 4 millones     Entre 21 y 30 horas
#
#    FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_EDUCACIONPADRE  \
# 0                     2                   1                   11
# 1                     2                   0                   10
# ...

# %% [markdown]
# Limpieza para ESTU_VALORMATRICULAUNIVERSIDAD

# %%
def limpieza_valormatricula(dataframe):
  # Asignar valores únicos a cada categoría (ignorando NaN)
  dataframe['ESTU_VALORMATRICULAUNIVERSIDAD'] = pd.factorize(dataframe['ESTU_VALORMATRICULAUNIVERSIDAD'])[0]

  # Calcular la media de los valores numéricos (ignorando NaN)
  media_valor = dataframe['ESTU_VALORMATRICULAUNIVERSIDAD'].replace(-1, np.nan).mean()

  # Reemplazar los valores NaN con la media
  dataframe['ESTU_VALORMATRICULAUNIVERSIDAD'] = dataframe['ESTU_VALORMATRICULAUNIVERSIDAD'].replace(-1, media_valor)
limpieza_valormatricula(z)

# %%
z.head()
# Out:
#    PERIODO  ESTU_PRGM_ACADEMICO  ESTU_PRGM_DEPARTAMENTO  \
# 0    20212                  300                       4
# 1    20212                  249                       3
# 2    20203                  819                       4
# 3    20195                   14                      26
# 4    20212                  907                       1
#
#    ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 0                             0.0       Menos de 10 horas
# 1                             1.0                       0
# 2                             1.0         Más de 30 horas
# 3                             2.0                       0
# 4                             1.0     Entre 21 y 30 horas
#
#    FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_EDUCACIONPADRE  \
# 0                     2                   1                   11
# 1                     2                   0                   10
# 2                     2                   1                    8
# ...

# %% [markdown]
# Limpieza para ESTU_HORASSEMANATRABAJA

# %%
import pandas as pd
import numpy as np

def limpiar_horas(dataframe):
    # Definir un diccionario con los rangos y sus valores representativos
    valores_map = {
        'Menos de 10 horas': 5,         # Promedio de 0 a 10 horas
        'Entre 11 y 20 horas': 15,      # Promedio de 11 a 20 horas
        'Entre 21 y 30 horas': 25,      # Promedio de 21 a 30 horas
        'Más de 30 horas': 35,          # Asignar valor arbitrario de 35 horas
        '0': 0                          # No trabaja
    }

    # Mapear las categorías de texto a los valores numéricos
    dataframe['ESTU_HORASSEMANATRABAJA'] = dataframe['ESTU_HORASSEMANATRABAJA'].map(valores_map)

    # Convertir los valores a tipo numérico, manejando los errores como NaN
    dataframe['ESTU_HORASSEMANATRABAJA'] = pd.to_numeric(dataframe['ESTU_HORASSEMANATRABAJA'], errors='coerce')

    # Calcular la media y desviación estándar de los valores diferentes a 0 para evitar sesgo
    mean_value = dataframe.loc[dataframe['ESTU_HORASSEMANATRABAJA'] > 0, 'ESTU_HORASSEMANATRABAJA'].mean()
    std_dev = dataframe.loc[dataframe['ESTU_HORASSEMANATRABAJA'] > 0, 'ESTU_HORASSEMANATRABAJA'].std()

    # Contar los valores NaN para imputar los valores faltantes
    missing_values_count = dataframe['ESTU_HORASSEMANATRABAJA'].isna().sum()

    # Sustituir los NaN generando valores aleatorios basados en una distribución normal
    dataframe.loc[dataframe['ESTU_HORASSEMANATRABAJA'].isna(), 'ESTU_HORASSEMANATRABAJA'] = np.random.normal(mean_value, std_dev, missing_values_count)

    return dataframe
limpiar_horas(z)
z.head()
# Out:
#    PERIODO  ESTU_PRGM_ACADEMICO  ESTU_PRGM_DEPARTAMENTO  \
# 0    20212                  300                       4
# 1    20212                  249                       3
# 2    20203                  819                       4
# 3    20195                   14                      26
# 4    20212                  907                       1
#
#    ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_HORASSEMANATRABAJA  \
# 0                             0.0                      5.0
# 1                             1.0                      0.0
# 2                             1.0                     35.0
# 3                             2.0                      0.0
# 4                             1.0                     25.0
#
#    FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_EDUCACIONPADRE  \
# 0                     2                   1                   11
# 1                     2                   0                   10
# 2                     2                   1                    8
# ...

# %% [markdown]
# # convert target (prediction) column into discrete values

# %%
y_col = 'RENDIMIENTO_GLOBAL'

rmap = {'alto': 3, 'bajo':0, 'medio-bajo':1, 'medio-alto':2}
z[y_col] = [rmap[i] for i in z[y_col]]
z.head()
# Out:
#    PERIODO  ESTU_PRGM_ACADEMICO  ESTU_PRGM_DEPARTAMENTO  \
# 0    20212                  300                       4
# 1    20212                  249                       3
# 2    20203                  819                       4
# 3    20195                   14                      26
# 4    20212                  907                       1
#
#    ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_HORASSEMANATRABAJA  \
# 0                             0.0                      5.0
# 1                             1.0                      0.0
# 2                             1.0                     35.0
# 3                             2.0                      0.0
# 4                             1.0                     25.0
#
#    FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_EDUCACIONPADRE  \
# 0                     2                   1                   11
# 1                     2                   0                   10
# 2                     2                   1                    8
# ...

# %% [markdown]
# #INICIO DEL MODELO SOLUCIÓN PARA ESTE ENTREGABLE (99)

# %% [markdown]
# build X and y for training a model
# observe we sort columns to make sure we always get the same ordering

# %%
z = z[sorted(z.columns)]

X = z[[c for c in z.columns if c!=y_col]].values
y = z[y_col].values
X.shape, y.shape
# Out:
# ((692500, 10), (692500,))

# %% [markdown]
# split into train and test

# %%
from sklearn.model_selection import train_test_split
Xtr, Xts, ytr, yts = train_test_split(X,y, train_size=0.8)
Xtr.shape, Xts.shape, ytr.shape, yts.shape
# Out:
# ((554000, 10), (138500, 10), (554000,), (138500,))

# %% [markdown]
# Make a random forest for classification
# train model

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, min_samples_split=2, min_samples_leaf=4, max_features= "sqrt", max_depth=20 ,random_state=42 )
rf.fit(Xtr, ytr)
# Out:
# RandomForestClassifier(max_depth=20, min_samples_leaf=4, random_state=42)

# %% [markdown]
# predicciones locales

# %%
preds_tr = rf.predict(Xtr)
preds_ts = rf.predict(Xts)

# %%
np.mean(preds_tr==ytr), np.mean(preds_ts==yts)
# Out:
# (0.6629765342960289, 0.4150036101083032)

# %% [markdown]
# # Reading and transforming test.csv

# %%
zt = pd.read_csv("test.csv")
zt
# Out:
#         Unnamed: 0      ID  PERIODO                     ESTU_PRGM_ACADEMICO  \
# 0                0  550236    20183                          TRABAJO SOCIAL
# 1                1   98545    20203  ADMINISTRACION COMERCIAL Y DE MERCADEO
# 2                2  499179    20212                  INGENIERIA MECATRONICA
# 3                3  782980    20195                      CONTADURIA PUBLICA
# 4                4  785185    20212              ADMINISTRACION DE EMPRESAS
# ...            ...     ...      ...                                     ...
# 296781      296781  496981    20195              ADMINISTRACION DE EMPRESAS
# 296782      296782  209415    20183                                 DERECHO
# 296783      296783  239074    20212                                 DERECHO
# 296784      296784  963852    20195                  INGENIERIA AERONAUTICA
# 296785      296785  792650    20212                   INGENIERIA INDUSTRIAL
#
# ...

# %%
zt_ids = zt['ID'].values
zt.drop('ID', axis=1, inplace=True)
zt.drop(columns=['Unnamed: 0'], inplace=True)
zt.head()
# Out:
#    PERIODO                     ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 0    20183                          TRABAJO SOCIAL                BOLIVAR
# 1    20203  ADMINISTRACION COMERCIAL Y DE MERCADEO              ANTIOQUIA
# 2    20212                  INGENIERIA MECATRONICA                 BOGOTÁ
# 3    20195                      CONTADURIA PUBLICA                  SUCRE
# 4    20212              ADMINISTRACION DE EMPRESAS              ATLANTICO
#
#              ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 0                          Menos de 500 mil       Menos de 10 horas
# 1  Entre 2.5 millones y menos de 4 millones     Entre 21 y 30 horas
# 2    Entre 1 millón y menos de 2.5 millones                       0
# 3    Entre 1 millón y menos de 2.5 millones     Entre 21 y 30 horas
# 4  Entre 2.5 millones y menos de 4 millones     Entre 11 y 20 horas
#
#   FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET  \
# 0            Estrato 3                 Si
# ...

# %% [markdown]
# Limpieza:

# %%
limpieza_valormatricula(zt)
cleaning_variables(zt)
limpiar_horas(zt)
zt.head()
# Out:
#    PERIODO  ESTU_PRGM_ACADEMICO  ESTU_PRGM_DEPARTAMENTO  \
# 0    20183                  914                       5
# 1    20203                   13                       1
# 2    20212                  449                       4
# 3    20195                  228                      27
# 4    20212                   14                       3
#
#    ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_HORASSEMANATRABAJA  \
# 0                             0.0                      5.0
# 1                             1.0                     25.0
# 2                             2.0                      0.0
# 3                             2.0                     25.0
# 4                             1.0                     15.0
#
#    FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_EDUCACIONPADRE  \
# 0                     2                   1                   10
# 1                     1                   1                    8
# 2                     2                   1                    9
# ...

# %% [markdown]
# create X array and predict

# %%
X_test_data = zt[sorted(zt.columns)].values
X_test_data.shape
# Out:
# (296786, 10)

# %%
preds_test_data = rf.predict(X_test_data)

# %% [markdown]
# <h2>prepare submission</h2>

# %%
# inverse mapping
rmapi = {v:k for k,v in rmap.items()}
text_preds_test_data = [rmapi[i] for i in preds_test_data]

# %%
# create dataframe
submission = pd.DataFrame([zt_ids, text_preds_test_data], index=['ID', 'RENDIMIENTO_GLOBAL']).T
submission
# Out:
#             ID RENDIMIENTO_GLOBAL
# 0       550236         medio-bajo
# 1        98545         medio-bajo
# 2       499179               alto
# 3       782980         medio-bajo
# 4       785185               bajo
# ...        ...                ...
# 296781  496981               bajo
# 296782  209415               alto
# 296783  239074         medio-alto
# 296784  963852               alto
# 296785  792650               alto
#
# [296786 rows x 2 columns]

# %%
# save to file ready to submit
submission.to_csv("my_submission.csv", index=False)

# %% [markdown]
# <h2>Send your submission to Kaggle</h2>

# %%
# !kaggle competitions submit -c udea-ai4eng-20242 -f my_submission.csv -m "random forest classifier"
# Out:
# 100% 4.10M/4.10M [00:00<00:00, 17.1MB/s]
# Successfully submitted to UDEA/ai4eng 20242 - Pruebas Saber Pro Colombia
